# %%
import requests
import pandas as pd

# %%
url = "https://api.infojobs.net/api/1/candidate/skillcategory?includeSkills=true"                                       
                                                                                                      
payload={}                                                                                           
headers = {                                                                                          
  'Authorization': 'Basic MWVlZDc3ZDJjZTJjNDQwMThiYWRjM2U0MGJkOTY1Y2E6RFBqYzdkMVNjNUlsRzRGTXZNVlFwaFA    4S2tXdkU2d0lnU3FYOW5rZ1Z0S2JaTkVzK1o=',                                                              
  'Cookie': 'IJUSERUID=3b364be8-a072-47b8-bac4-34f29903ceb4; JSESSIONID=TJpfc6KysyOynUJQl3roTCKE'    
}                                                                                                    
                                                                                                      
response = requests.request("GET", url, headers=headers, data=payload)                               
                                                                                                     
data_1 = response.json() if response and response.status_code == 200 else None

data_1[0]
# Out:
# {'id': 13,
#  'name': 'Idiomas',
#  'order': 13,
#  'parentCategoryId': 0,
#  'skills': [],
#  'subcategories': [{'id': 1301,
#    'name': 'Dominio de idiomas',
#    'order': 1301,
#    'parentCategoryId': 13,
#    'skills': [{'id': 1,
#      'name': 'Español',
#      'type': 'language',
#      'order': 1,
#      'key': 'espanol',
#      'deprecated': False},
#     {'id': 2,
#      'name': 'Catalán',
#      'type': 'language',
#      'order': 2,
#      'key': 'catalan',
#      'deprecated': False},
#     {'id': 3,
#      'name': 'Inglés',
#      'type': 'language',
#      'order': 3,
#      'key': 'ingles',
#      'deprecated': False},
#     {'id': 4,
#      'name': 'Alemán',
#      'type': 'language',
#      'order': 4,
#      'key': 'aleman',
#      'deprecated': False},
#     {'id': 5,
#      'name': 'Italiano',
#      'type': 'language',
#      'order': 5,
#      'key': 'italiano',
#      'deprecated': False},
#     {'id': 6,
#      'name': 'Portugués',
#      'type': 'language',
#      'order': 6,
#      'key': 'portugues',
#      'deprecated': False},
#     {'id': 7,
#      'name': 'Francés',
#      'type': 'language',
#      'order': 7,
#      'key': 'frances',
#      'deprecated': False},
#     {'id': 8,
#      'name': 'Árabe',
#      'type': 'language',
#      'order': 8,
#      'key': 'arabe',
#      'deprecated': False},
#     {'id': 9,
#      'name': 'Checo',
#      'type': 'language',
#      'order': 9,
#      'key': 'checo',
#      'deprecated': False},
#     {'id': 10,
#      'name': 'Chino',
#      'type': 'language',
#      'order': 10,
#      'key': 'chino',
#      'deprecated': False},
#     {'id': 11,
#      'name': 'Croata',
#      'type': 'language',
#      'order': 11,
#      'key': 'croata',
#      'deprecated': False},
#     {'id': 12,
#      'name': 'Danés',
#      'type': 'language',
#      'order': 12,
#      'key': 'danes',
#      'deprecated': False},
#     {'id': 13,
#      'name': 'Eslovaco',
#      'type': 'language',
#      'order': 13,
#      'key': 'eslovaco',
#      'deprecated': False},
#     {'id': 14,
#      'name': 'Esloveno',
#      'type': 'language',
#      'order': 14,
#      'key': 'esloveno',
#      'deprecated': False},
#     {'id': 15,
#      'name': 'Euskera',
#      'type': 'language',
#      'order': 15,
#      'key': 'euskera',
#      'deprecated': False},
#     {'id': 16,
#      'name': 'Finlandés',
#      'type': 'language',
#      'order': 16,
#      'key': 'finlandes',
#      'deprecated': False},
#     {'id': 17,
#      'name': 'Gallego',
#      'type': 'language',
#      'order': 17,
#      'key': 'gallego',
#      'deprecated': False},
#     {'id': 18,
#      'name': 'Griego',
#      'type': 'language',
#      'order': 18,
#      'key': 'griego',
#      'deprecated': False},
#     {'id': 19,
#      'name': 'Húngaro',
#      'type': 'language',
#      'order': 19,
#      'key': 'hungaro',
#      'deprecated': False},
#     {'id': 20,
#      'name': 'Japonés',
#      'type': 'language',
#      'order': 20,
#      'key': 'japones',
#      'deprecated': False},
#     {'id': 21,
#      'name': 'Holandés',
#      'type': 'language',
#      'order': 21,
#      'key': 'holandes',
#      'deprecated': False},
#     {'id': 22,
#      'name': 'Noruego',
#      'type': 'language',
#      'order': 22,
#      'key': 'noruego',
#      'deprecated': False},
#     {'id': 23,
#      'name': 'Polaco',
#      'type': 'language',
#      'order': 23,
#      'key': 'polaco',
#      'deprecated': False},
#     {'id': 24,
#      'name': 'Rumano',
#      'type': 'language',
#      'order': 24,
#      'key': 'rumano',
#      'deprecated': False},
#     {'id': 25,
#      'name': 'Ruso',
#      'type': 'language',
#      'order': 25,
#      'key': 'ruso',
#      'deprecated': False},
#     {'id': 26,
#      'name': 'Serbio',
#      'type': 'language',
#      'order': 26,
#      'key': 'serbio',
#      'deprecated': False},
#     {'id': 27,
#      'name': 'Sueco',
#      'type': 'language',
#      'order': 27,
#      'key': 'sueco',
#      'deprecated': False},
#     {'id': 28,
#      'name': 'Turco',
#      'type': 'language',
#      'order': 28,
#      'key': 'turco',
#      'deprecated': False},
#     {'id': 2013129312,
#      'name': 'Otro Idioma',
#      'type': 'language',
#      'order': 2013129312,
#      'key': 'otro-idioma',
#      'deprecated': False}],
#    'subcategories': []},
#   {'id': 1302,
#    'name': 'Traducción e interpretación',
#    'order': 1302,
#    'parentCategoryId': 13,
#    'skills': [{'id': 172789157,
#      'name': 'Traducción jurídico-administrativa',
#      'type': 'expertise',
#      'order': 172789157,
#      'key': 'traduccion-juridico-administrativa',
#      'deprecated': False},
#     {'id': 172789158,
#      'name': 'Traducción literaria',
#      'type': 'expertise',
#      'order': 172789158,
#      'key': 'traduccion-literaria',
#      'deprecated': False},
#     {'id': 172789159,
#      'name': 'Traducción informática',
#      'type': 'expertise',
#      'order': 172789159,
#      'key': 'traduccion-informatica',
#      'deprecated': False},
#     {'id': 172789160,
#      'name': 'Traducción médica',
#      'type': 'expertise',
#      'order': 172789160,
#      'key': 'traduccion-medica',
#      'deprecated': False},
#     {'id': 172789161,
#      'name': 'Traducción social',
#      'type': 'expertise',
#      'order': 172789161,
#      'key': 'traduccion-social',
#      'deprecated': False},
#     {'id': 172789163,
#      'name': 'Interpretación simultánea',
#      'type': 'expertise',
#      'order': 172789163,
#      'key': 'interpretacion-simultanea',
#      'deprecated': False},
#     {'id': 172789164,
#      'name': 'Interpretación consecutiva',
#      'type': 'expertise',
#      'order': 172789164,
#      'key': 'interpretacion-consecutiva',
#      'deprecated': False},
#     {'id': 2013127110,
#      'name': 'Herramientas de traducción asistida',
#      'type': 'expertise',
#      'order': 2013127110,
#      'key': 'herramientas-de-traduccion-asistida',
#      'deprecated': False},
#     {'id': 2013127112,
#      'name': 'Interpretación de lenguaje de signos',
#      'type': 'expertise',
#      'order': 2013127112,
#      'key': 'interpretacion-de-lenguaje-de-signos',
#      'deprecated': False},
#     {'id': 2013127114,
#      'name': 'Traducción de aplicaciones informáticas',
#      'type': 'expertise',
#      'order': 2013127114,
#      'key': 'traduccion-de-aplicaciones-informaticas',
#      'deprecated': False},
#     {'id': 2013127116,
#      'name': 'Traducción de ingeniería',
#      'type': 'expertise',
#      'order': 2013127116,
#      'key': 'traduccion-de-ingenieria',
#      'deprecated': False},
#     {'id': 2013127118,
#      'name': 'Traducción jurada',
#      'type': 'expertise',
#      'order': 2013127118,
#      'key': 'traduccion-jurada',
#      'deprecated': False},
#     {'id': 2013127120,
#      'name': 'Traducción jurídico-administrativa',
#      'type': 'expertise',
#      'order': 2013127120,
#      'key': 'traduccion-juridico-administrativa',
#      'deprecated': False},
#     {'id': 2013127122,
#      'name': 'Traducción periodística',
#      'type': 'expertise',
#      'order': 2013127122,
#      'key': 'traduccion-periodistica',
#      'deprecated': False},
#     {'id': 2013127124,
#      'name': 'Traducción publicitaria',
#      'type': 'expertise',
#      'order': 2013127124,
#      'key': 'traduccion-publicitaria',
#      'deprecated': False}],
#    'subcategories': []}]}

# %%
url = "https://api.infojobs.net/api/1/candidate/skillcategory?includeSkills=true"
response = requests.request("GET", url, headers=headers, data=payload)
data_6 = response.json() if response and response.status_code == 200 else None
for i in range(len(data_6)):...
    #print(data_6[0]['skills'])
len(data_6)
# Out:
# 23

# %%
#DICT sc-id to sc-str
url = "https://api.infojobs.net/api/7/offer?category=informatica-telecomunicaciones&maxResults=100"

response = requests.request("GET", url, headers=headers, data=payload)                                                                   
data_2 = response.json() if response and response.status_code == 200 else None
sc_id_to_name= {}
for i in range(len(data_2['items'])):
    sc_id_to_name[data_2['items'][i]['subcategory']['id']]=data_2['items'][i]['subcategory']['value']
# Out:
# {3124: 'Programación',
#  3111: 'Hardware, redes y seguridad',
#  3112: 'Helpdesk',
#  3114: 'Telecomunicaciones',
#  3105: 'Administración de bases de datos',
#  3113: 'Sistemas',
#  3107: 'Arquitectura',
#  3109: 'ERP, CRM, Business Intelligence',
#  3108: 'Calidad',
#  3106: 'Análisis',
#  3110: 'Gestión de proyectos'}

# %%
#LIST OF JOBS
url = "https://api.infojobs.net/api/7/offer?category=informatica-telecomunicaciones&maxResults=10"
response = requests.request("GET", url, headers=headers, data=payload)     
                                                                              
data_5 = response.json() if response and response.status_code == 200 else None
data_5['items'][0]
# Out:
# {'id': '670115a6b044309cc5014f8bdb1622',
#  'title': 'Técnico Informático',
#  'province': {'id': 17, 'value': 'Córdoba'},
#  'city': 'Córdoba',
#  'link': 'https://www.infojobs.net/cordoba/tecnico-informatico/of-i670115a6b044309cc5014f8bdb1622',
#  'category': {'id': 150, 'value': 'Informática y telecomunicaciones'},
#  'contractType': {'id': 1, 'value': 'Indefinido'},
#  'subcategory': {'id': 3111, 'value': 'Hardware, redes y seguridad'},
#  'salaryMin': {'id': 0, 'value': ''},
#  'salaryMax': {'id': 0, 'value': ''},
#  'salaryPeriod': {'id': 0, 'value': ''},
#  'experienceMin': {'id': 6, 'value': 'Al menos 2 años'},
#  'workDay': {'id': 2, 'value': 'Parcial - Mañana'},
#  'study': {'id': 60, 'value': 'Ciclo Formativo Grado Superior'},
#  'published': '2022-04-09T18:00:19.000Z',
#  'updated': '2022-04-30T19:30:02.000Z',
#  'author': {'id': '98485352485553837369324022097124806135',
#   'name': 'SIE CONSULTORES INFORMATICOS SL.',
#   'uri': 'https://www.infojobs.net/sie-consultores-informaticos-sl./em-i98485352485553837369324022097124806135',
#   'logoUrl': 'https://multimedia.infojobs.net/api/v1/tenants/c7e2b9c1-8480-43b0-ad9e-000c17aa2cbb/domains/718302b6-5343-43d3-a8a3-829dc3da0893/buckets/6f3ab1cc-5920-4f4e-b131-46a4587a0e1f/images/8c/8c5307e2-f5fe-4c31-8acc-212dc23ac0c0?jwt=eyJhbGciOiJSUzI1NiJ9..SqNQy8ZjbKLVHTRBDKSGc8umlXOaq0RyGQU2a5hCmaLzKGKgwocRHpQMrjotemzRIejuHjwCi2LxtFG5fT2Y7LgqoGT3jNxUj5Pc80DsOz9iZJqifYVuUr8tU3h4a_Zf7Nlq31WP-AD1ycj8YccCHfm_PFGZShYGNOD7MncMAXImSTwgI1b5ql1GZoHpGgma7X18JWeHp-I_HtCSo-3Xz9y6cpGSy3j4I59szEEHsW7IivyajEsaAvtaRGskUP8SuIUcT-dc-NViittK3Wsc-jK8mC3g8UjcTmoI6sKlzy9XjrsVYOmlareOnWerco1fxHjSAxSN3ilAFWWA3p9NAQ&AccessKeyId=d724d9a53d95a810',
#   'corporateResponsive': False,
#   'showCorporativeHeader': False},
#  'requirementMin': '',
#  'bold': False,
#  'applications': '0',
#  'subSegment': 22,
#  'executive': False,
#  'salaryDescription': 'Salario no disponible',
#  'urgent': False,
#  'color': False}

# %%
def jobs_from_sc(sc_id:str): #given sc id
    #from id to str
    sc=sc_id
    url= "https://api.infojobs.net/api/7/offer?subcategory="+sc+"&maxResults=100"
    response = requests.request("GET", url, headers=headers, data=payload)                                                                                 
    data = response.json() if response and response.status_code == 200 else None
    job_list=[]
    for i in range(len(data['items'])):
        job_list.append(data['items'][i]['id'])
    return job_list

def sc_to_joblist_map():
    map = {}
    for i in range(): ...
# Out:
# ['6d656237714dafbfedc0b30e44c57b',
#  'f0cb2531f44ccb9ad80fa6477d1335',
#  '39d3ae00134b33bdffefb084e56b61',
#  '79606d67554ab7a93af6a00e9b6e0d',
#  'dcdb603d6e43a7898db48276387765',
#  '73f096f7f54a378738d50dfee296eb',
#  '5a461329d54884a01016989f2cd666',
#  'e38bdbd48547a59ac2beb8303cac24',
#  '6e5cb56b2b4219bd3a25d099bdcc8f',
#  'c9d1ab93114847bc82da9e321dcd62',
#  'bea168f96b404f914c7f022b82a7f5',
#  '59f1cb9cbf453db0deb9bf29327329',
#  'befb28fcf645c48edc1466e37d26b2',
#  'ae88c14be74880b92f961757568486',
#  '3bede95b0e4796a7ae1e6a28a53920',
#  '8d10f49c90405f8e38bba4cc06edb2',
#  '32509ac72841ba96a637486b3eda1c',
#  'e55c8a9ba7465b9dd5d90f882c2d45',
#  'fa1508265e41f8852fb1ccaf0ff5b0',
#  '215bb6666b498a94bf100a2fcec230',
#  'f5618935874d4aaa1664a069bea79f',
#  'cf55afd5cd4d069a49498a92deb7d4',
#  'e5194f6f7a499abf1bc4706c760912',
#  '50619e4a054a7ca6ee702828dd17cb',
#  '7f3149d30549c889af586787d39ecc',
#  '1d13a190ac48208beb00994462c7a4',
#  'dd7083c59445bdbf3d6941d17ee9f1',
#  '8c49278d634d32827215ccf22225ac',
#  'f856c7868e4d3db1be961e86de9fee',
#  'cabc1a4c664c979d781874f60fe3f5',
#  '377af91f2f4281a4ed562c8213ab8a',
#  '99b5154c454f4ea1976cd449375765',
#  '803a4b93d1453eb6b8585015c0d638',
#  'b1e7dae9b14f7ea0162f67883d33e8',
#  '4c8390c3b3432785ad9b738701aa73',
#  'c6ad43f3ac4b8e917409039c0a60f9',
#  'eb6a190972404ea7fe22b796c9b874',
#  '8237b028264a6592e06f3125c574be',
#  'a322774e9546dba67a33920f3964ca',
#  'edb45f794a4bc381d1399ac92b7957',
#  '0e411d77da46e4814fb87ec82affff',
#  '303f707f3e4a54a84301d01cf94e6b',
#  '60b32eccd441228fad0158f6085fc8',
#  'ffcb562ad5483dad51e47bdf72673f',
#  'f2c44305434b8784f01bde21cf5847',
#  '5014c45c9f4c11a07e57c9e22f2b52',
#  '385fa7ec9b4303aaf2c2a4e48d9dd0',
#  'dccacb642b45639149106ceb693513',
#  '22db67d2ec47f09b8e2a4e13a0e3f6',
#  '549b897a114e3fa6147d658fb6497c',
#  '593daae5da415bb17a2323187a785e',
#  'f3716a90e84daf89cf42718109afd3',
#  'e56cd11ceb472288ec0623aeaec01d',
#  '6a19d93ba64a23be33716f0c3559ce',
#  'b06c87cca84473b974c79bfb59c734',
#  '29a4474305477bb2c36e567d6575b3',
#  '1d9e1de2b2482bb7bbf62b589c0a30',
#  '0b5b199a534b89be1c1f28f56005d7',
#  'ee1c6e23a5491d83c325a2c44be300',
#  'fdca1c4c0a4ef19ef3315c971c9cff',
#  '691786f1f649239feee4bd98add99a',
#  '176d57d3684024bb402a6f48814447',
#  '46508d101a4ad6a99a41d080c09e00',
#  '415af6c10c476c94e7c612ce7d9e28',
#  'b12d1171d4415388fd878d0281505b',
#  '555f81aca7441a8d26504657c9d3d1',
#  'af5f1df5bb41f18ddb315993fddf87',
#  '517c2a08ec4c68a100350e45fbc853',
#  'dbaa0a4504405c801566fa9c9377c1',
#  '9158d20d674484b84104f9f78bc295',
#  '51dc3d868d43abb941ee31b4190219',
#  '1ecfca065a4754926060f86bf2f885',
#  'c353411ee34c49916b44d7f1f43ea5',
#  'd0cb01daf44f3491c6e66d41d519a7',
#  'd865ac330b40b4aaf5e8cd6fc17d8c',
#  'e9caeeeca84f3fadee077ce5e1d674',
#  'fbcfcdc282440ea4b3f657f2ebe399',
#  'a8eace1fff4d00a5ef3c15a5661778',
#  '8d0e822bc1400f9d8317d98adb8ab3',
#  'c1c9c85fab42d292851b5624831425',
#  '819d9410db4438b24b7863d5dacc1a',
#  '1260d3feae4d68ba1d0ca44a112a30',
#  '28580d396641d2b0f33e09b74a3f30',
#  'c4a119728e4ae584a52e17b4c6048a',
#  '29edafce574a8eb043c968ed40dde0',
#  '268fe989d04863962474dc8c2e62ed',
#  '911c90b1c04238b20517cc22225f18',
#  'fe4868820c43d185afcc489ada8b8b',
#  '403abfe3b248b3910485f5fd37da68',
#  '1582dacb5a4f7a83597876c352c6c9',
#  '4dfc73683c4bbcb6793a3c449da2fa',
#  '0e4f4ae7dc49d6bf88dd7fcf031466',
#  '23c4da418847f98c46c8a13bed6cf5',
#  'a53c65258948bca3cbd33b289c97e5',
#  '7f637e30db4674b5c74ee18ccaeeba',
#  '02b9dd88e94c2bbec1a31da1f9d874',
#  'd509e15d7345b8bb3e63ed9fb55369',
#  '7931f888c745589f909dfd7ac934bc',
#  'feb4a1ceee4350affa4b36ff2b24db',
#  '883fb1dda2464d94cf94606cf8d84c']
