# %%
import requests
import pandas as pd

# %%
url = "https://api.infojobs.net/api/1/candidate/skillcategory"                                       
                                                                                                      
payload={}                                                                                           
headers = {                                                                                          
  'Authorization': 'Basic MWVlZDc3ZDJjZTJjNDQwMThiYWRjM2U0MGJkOTY1Y2E6RFBqYzdkMVNjNUlsRzRGTXZNVlFwaFA    4S2tXdkU2d0lnU3FYOW5rZ1Z0S2JaTkVzK1o=',                                                              
  'Cookie': 'IJUSERUID=3b364be8-a072-47b8-bac4-34f29903ceb4; JSESSIONID=TJpfc6KysyOynUJQl3roTCKE'    
}                                                                                                    
                                                                                                      
response = requests.request("GET", url, headers=headers, data=payload)                               
                                                                                                     
data = response.json() if response and response.status_code == 200 else None

# %%
len(data)
# Out:
# 23

# %%
for i in range(len(data)):
    print(data[i]['name'])
# Out:
# Idiomas
# Agrario y alimentario
# Calidad, I+D e innovación
# Compras, logística y transportes
# Comunicación y audiovisual
# Deporte y ocio
# Derecho y justicia
# Dirección y administración
# Diseño y artes gráficas
# Electricidad, electrónica, mecánica
# Finanzas y contabilidad
# Hostelería, turismo y hogar
# Humanidades y actividades socioculturales
# Informática y telecomunicaciones
# Ingenierías e industria
# Inmobiliario y construcción
# Marketing y ventas
# Música, teatro y danza
# Naval y pesquero
# RRHH y formación
# Sanidad y salud
# Seguridad y ejército
# Textil, moda y estética

# %%
it_skills = {}

for i in range(len(data)):
    if data[i]['id'] == 14:
        starting_id = data[i]['subcategories'][0]['id']
        for j in range(len(data[i]['subcategories'])):
            it_skills[data[i]['subcategories'][j]['name']] = data[i]['subcategories'][j]['id']

# %%
list_skills=[]
for s in it_skills:
    list_skills.append(s)

# %%
list_skills
# Out:
# ['Administración de sistemas',
#  'Análisis y gestión de bases de datos',
#  'Análisis y programación',
#  'Aplicaciones y servidores de mensajería',
#  'Arquitectura y diseño de hardware',
#  'Business inteligence',
#  'Calidad del software',
#  'Consultoría de sistemas',
#  'Consultoría y desarrollo ERP',
#  'Desarrollo de firmware',
#  'Desarrollo multimedia',
#  'Dirección técnica de sistemas de información',
#  'Dirección y gestión de telecomunicaciones',
#  'Diseño web',
#  'Estándares y protocolos de redes',
#  'Estándares y tecnologías de hardware',
#  'Estándares y tecnologías de telecomunicación',
#  'Gestión de contenidos',
#  'Gestión de proyectos informáticos',
#  'Gestión de redes',
#  'Gestión de servicios informáticos',
#  'Gestion documental, ECM, Imaging…',
#  'Gestión documental, ECM, Imaging…',
#  'Groupware, workflow, BPM',
#  'Herramientas de desarrollo',
#  'Herramientas de diseño web y multimedia',
#  'Herramientas ERP y business inteligence',
# ...

# %%
for i in range(len(data)):

# %%
len(it_skills)
# Out:
# 41

# %%
url = "https://api.infojobs.net/api/1/candidate/skill"

skills = {}
                              
                                                                                                     
for skill in it_skills:                                                                                                        
    response = requests.request("GET", url + "?categoryId=" + str(it_skills[skill]), headers=headers, data=payload) 
    data = response.json() if response and response.status_code == 200 else None
    for i in range(len(data)):
        print(data[i])
# Out:
# {'id': 172788499, 'name': 'Operaciones de backup y restore', 'type': 'expertise', 'order': 172788499, 'key': 'operaciones-de-backup-y-restore', 'deprecated': False}
# {'id': 172788500, 'name': 'Seguimiento de incidencias informáticas', 'type': 'expertise', 'order': 172788500, 'key': 'seguimiento-de-incidencias-informaticas', 'deprecated': False}
# {'id': 172788501, 'name': 'Soporte informático a clientes', 'type': 'expertise', 'order': 172788501, 'key': 'soporte-informatico-a-clientes', 'deprecated': False}
# {'id': 172788502, 'name': 'Actualización de versiones de ofimática', 'type': 'expertise', 'order': 172788502, 'key': 'actualizacion-de-versiones-de-ofimatica', 'deprecated': False}
# {'id': 172788503, 'name': 'Configuración de sistemas', 'type': 'expertise', 'order': 172788503, 'key': 'configuracion-de-sistemas', 'deprecated': False}
# ...

# %%
url = "https://api.infojobs.net/api/7/offer?category=informatica-telecomunicaciones&maxResults=600"
response = requests.request("GET", url, headers=headers, data=payload)                               
                                                                                                     
data = response.json() if response and response.status_code == 200 else None
for i in range(len(data['items'])):
    if data['items'][i] is None:
        print(i)

# %%
data['items'][0]
# Out:
# {'id': 'f0cb2531f44ccb9ad80fa6477d1335',
#  'title': 'ANALISTA PROGRAMADOR .NET EN ANDORRA LA VELLA 3 años de Experiencia',
#  'province': {'id': 402, 'value': 'Andorra la Vella'},
#  'city': 'Andorra',
#  'link': 'https://www.infojobs.net/andorra/analista-programador-.net-andorra-vella-3-anos-experiencia/of-if0cb2531f44ccb9ad80fa6477d1335',
#  'category': {'id': 150, 'value': 'Informática y telecomunicaciones'},
#  'contractType': {'id': 1, 'value': 'Indefinido'},
#  'subcategory': {'id': 3124, 'value': 'Programación'},
#  'salaryMin': {'id': 285, 'value': '33.000 €'},
#  'salaryMax': {'id': 295, 'value': '39.000 €'},
#  'salaryPeriod': {'id': 3, 'value': 'Bruto/año'},
#  'experienceMin': {'id': 3, 'value': 'Al menos 3 años'},
#  'workDay': {'id': 1, 'value': 'Completa'},
#  'study': {'id': 60, 'value': 'Ciclo Formativo Grado Superior'},
#  'published': '2022-04-23T18:04:14.000Z',
#  'updated': '2022-04-30T18:30:02.000Z',
#  'author': {'id': '952256524533201740655945055155',
# ...

# %%
url = "https://api.infojobs.net/api/7/offer?category=informatica-telecomunicaciones&maxResults=600"
response = requests.request("GET", url, headers=headers, data=payload)     
                                                                              
data = response.json() if response and response.status_code == 200 else None

jlist_from_categories = {}
for i in range (len(data['items'])):
    key_list=jlist_from_categories.keys()
    if data['items'][i]['subcategory']['value'] not in key_list:
        if data['items'][i]['subcategory'] is not None:
            jlist_from_categories[data['items'][i]['subcategory']['value']]=[data['items'][i]['id']]
    else:
        jlist_from_categories[data['items'][i]['subcategory']['value']].append(data['items'][i]['id'])

jlist_from_categories
# Out:
# {'Programación': ['f0cb2531f44ccb9ad80fa6477d1335',
#   '39d3ae00134b33bdffefb084e56b61',
#   '79606d67554ab7a93af6a00e9b6e0d',
#   'dcdb603d6e43a7898db48276387765',
#   '73f096f7f54a378738d50dfee296eb',
#   '5a461329d54884a01016989f2cd666',
#   'e38bdbd48547a59ac2beb8303cac24',
#   '6e5cb56b2b4219bd3a25d099bdcc8f',
#   'c9d1ab93114847bc82da9e321dcd62',
#   'bea168f96b404f914c7f022b82a7f5',
#   '59f1cb9cbf453db0deb9bf29327329',
#   'befb28fcf645c48edc1466e37d26b2',
#   'ae88c14be74880b92f961757568486',
#   '3bede95b0e4796a7ae1e6a28a53920',
#   '8d10f49c90405f8e38bba4cc06edb2',
#   '32509ac72841ba96a637486b3eda1c',
#   'e55c8a9ba7465b9dd5d90f882c2d45',
#   '215bb6666b498a94bf100a2fcec230',
#   'fa1508265e41f8852fb1ccaf0ff5b0',
#   'f5618935874d4aaa1664a069bea79f',
#   'cf55afd5cd4d069a49498a92deb7d4',
#   '50619e4a054a7ca6ee702828dd17cb',
#   'e5194f6f7a499abf1bc4706c760912',
#   '7f3149d30549c889af586787d39ecc',
#   '1d13a190ac48208beb00994462c7a4',
# ...

# %%
url = "https://api.infojobs.net/api/7/offer?subcategory=Programacion&maxResults=10"
response = requests.request("GET", url, headers=headers, data=payload)     
                                                                              
data = response.json() if response and response.status_code == 200 else None
data['items'][0]
# Out:
# {'id': 'f0cb2531f44ccb9ad80fa6477d1335',
#  'title': 'ANALISTA PROGRAMADOR .NET EN ANDORRA LA VELLA 3 años de Experiencia',
#  'province': {'id': 402, 'value': 'Andorra la Vella'},
#  'city': 'Andorra',
#  'link': 'https://www.infojobs.net/andorra/analista-programador-.net-andorra-vella-3-anos-experiencia/of-if0cb2531f44ccb9ad80fa6477d1335',
#  'category': {'id': 150, 'value': 'Informática y telecomunicaciones'},
#  'contractType': {'id': 1, 'value': 'Indefinido'},
#  'subcategory': {'id': 3124, 'value': 'Programación'},
#  'salaryMin': {'id': 285, 'value': '33.000 €'},
#  'salaryMax': {'id': 295, 'value': '39.000 €'},
#  'salaryPeriod': {'id': 3, 'value': 'Bruto/año'},
#  'experienceMin': {'id': 3, 'value': 'Al menos 3 años'},
#  'workDay': {'id': 1, 'value': 'Completa'},
#  'study': {'id': 60, 'value': 'Ciclo Formativo Grado Superior'},
#  'published': '2022-04-23T18:04:14.000Z',
#  'updated': '2022-04-30T18:30:02.000Z',
#  'author': {'id': '952256524533201740655945055155',
# ...

# %%
def jobs_from_sc(sc_id:str): #given sc id
    #from id to str
    url= "https://api.infojobs.net/api/7/offer?subcategory="+sc+"&maxResults=100"
    response = requests.request("GET", url, headers=headers, data=payload)                                                                                 
    data = response.json() if response and response.status_code == 200 else None
    job_list=[]
    for i in range(len(data['items'])):
        job_list.append(data['items'][i]['id'])
    return job_list

def sc_to_joblist_map(sc_id:str):
    map = {}
    for i in range()
# Out:
# ['6d656237714dafbfedc0b30e44c57b',
#  'f0cb2531f44ccb9ad80fa6477d1335',
#  '39d3ae00134b33bdffefb084e56b61',
#  '79606d67554ab7a93af6a00e9b6e0d',
#  'dcdb603d6e43a7898db48276387765',
#  '73f096f7f54a378738d50dfee296eb',
#  '5a461329d54884a01016989f2cd666',
#  'e38bdbd48547a59ac2beb8303cac24',
#  '6e5cb56b2b4219bd3a25d099bdcc8f',
#  'c9d1ab93114847bc82da9e321dcd62',
#  'bea168f96b404f914c7f022b82a7f5',
#  '59f1cb9cbf453db0deb9bf29327329',
#  'befb28fcf645c48edc1466e37d26b2',
#  'ae88c14be74880b92f961757568486',
#  '3bede95b0e4796a7ae1e6a28a53920',
#  '8d10f49c90405f8e38bba4cc06edb2',
#  '32509ac72841ba96a637486b3eda1c',
#  'e55c8a9ba7465b9dd5d90f882c2d45',
#  'fa1508265e41f8852fb1ccaf0ff5b0',
#  '215bb6666b498a94bf100a2fcec230',
#  'f5618935874d4aaa1664a069bea79f',
#  'cf55afd5cd4d069a49498a92deb7d4',
#  'e5194f6f7a499abf1bc4706c760912',
#  '50619e4a054a7ca6ee702828dd17cb',
#  '7f3149d30549c889af586787d39ecc',
#  '1d13a190ac48208beb00994462c7a4',
#  'dd7083c59445bdbf3d6941d17ee9f1',
# ...
