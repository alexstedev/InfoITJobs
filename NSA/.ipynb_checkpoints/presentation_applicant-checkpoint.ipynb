# %%
import json
from typing import Dict, List
from Priority_queue_v import Priority_queue as pq


def divide(v: List, n: int) -> List:
    for i in range(len(v)):
        v[i] /= n
    return v


def sum_vec(v1: List, v2: List) -> List:
    v = []
    for i in range(len(v1)):
        v += [v1[i]+v2[i]]
    return v


def norm2(v1: List, v2: List) -> float:
    s = 0
    for i in range(len(v1)-1):
        s += (v1[i]-v2[i])**2
    return s


def add_activity(v: List, new_v: List) -> List:
    return sum_vec(v, new_v)


def applicant_vector(profile: List, activity: List, n: int) -> List:
    return divide(profile + divide(activity, n), 2)


def build_first(sc_matrix: List[List], applicant: List, k: int) -> List:
    # given list of k sc_matrix, returns the extension with euclidean distance squared.
    for i in range(len(sc_matrix)):
        sc_matrix[i] += [norm2(sc_matrix[i], applicant)]
    return sc_matrix


skills = []
profile = []
activity = []
k = 10
act_num = 1
# applicant = applicant_vector(profile, activity, act_num)

# Layer 1.


def keystoint(x):
    return {int(k): v for k, v in x.items()}


def retrieve_data():
    with open('sc_id_to_name.json') as file:
        M = json.load(file)
    with open('category_matrix.json') as file:
        sc_matrix = json.load(file)
    with open('skills_id_to_name.json') as file:
        v = json.load(file)
    return M, sc_matrix, v


def search_engine(Q: pq, sc_matrix: List[List], applicant: List) -> List:
    # Q already has the first k elements.
    for i in range(len(sc_matrix)):
        Q.insert(sc_matrix[i])
        Q.remove_max()
    return Q.queue_to_list()
# Out:
# {'1401': 'Administración de sistemas', '1402': 'Análisis y gestión de bases de datos', '1403': 'Análisis y programación', '1404': 'Aplicaciones y servidores de mensajería', '1405': 'Arquitectura y diseño de hardware', '1406': 'Business inteligence', '1407': 'Calidad del software', '1408': 'Consultoría de sistemas', '1409': 'Consultoría y desarrollo ERP', '1410': 'Desarrollo de firmware', '1411': 'Desarrollo multimedia', '1412': 'Dirección técnica de sistemas de información', '1413': 'Dirección y gestión de telecomunicaciones', '1414': 'Diseño web', '1415': 'Estándares y protocolos de redes', '1416': 'Estándares y tecnologías de hardware', '1417': 'Estándares y tecnologías de telecomunicación', '1418': 'Gestión de contenidos', '1419': 'Gestión de proyectos informáticos', '1420': 'Gestión de redes', '1421': 'Gestión de servicios informáticos', '1422': 'Gestion documental, ECM, Imaging…', '1423': 'Gestión documental, ECM, Imaging…', '1424': 'Groupware, workflow, BPM', '1425': 'Herramientas de desarrollo', '1426': 'Herramientas de diseño web y multimedia', '1427': 'Herramientas ERP y business inteligence', '1428': 'Informática sectorial', '1429': 'Ingeniería de telecomunicaciones', '1430': 'Instalación de telecomunicaciones', '1431': 'Lenguajes de programación', '1432': 'Métodos, estándares y API', '1433': 'Ofimática', '1434': 'Otros programas', '1435': 'Plataformas hardware', '1436': 'Seguridad informática', '1437': 'Sistemas operativos', '1438': 'Soporte a usuarios y helpdesk', '1439': 'Tecnologías de bases de datos', '1440': 'Tecnologías de redes', '1441': 'Venta de informática y telecomunicaciones'}
# ['Desarrollo multimedia', 'Estándares y tecnologías de telecomunicación', 'Arquitectura y diseño de hardware', 'Gestion documental, ECM, Imaging…', 'Gestión documental, ECM, Imaging…', 'Groupware, workflow, BPM', 'Informática sectorial', 'Métodos, estándares y API', 'Otros programas', 'Plataformas hardware']

# %%
def print_skills(M):
    applicant = []
    print("Possible skills: ")
    for i in v:
        print(i, v[i])

M, sc_matrix, v = retrieve_data()
print_skills(M)
# Out:
# Possible skills:
# 172788296 Administración del entorno desktop
# 172788297 Administración de dispositivos
# 172788300 Administración de entornos mainframe
# 172788378 Administración de usuarios
# 172788379 Configuración de sistemas hardware
# 172788381 Rendimiento de sistemas
# 172788382 Instalación de software de sistemas
# 172788384 Gestión de sistemas de almacenamiento
# 172788385 Gestión de sistemas de help desk
# 172788387 Monitores de sistemas mainframe
# 172788388 Monitorización del rendimiento web
# 172788390 Planificación de jobs
# 172788395 BMC utilities
# 172788396 Tivoli
# 172788397 Endevor
# 172788398 Unicenter TNG
# 172788499 Operaciones de backup y restore
# 172788500 Seguimiento de incidencias informáticas
# 172788501 Soporte informático a clientes
# 172788502 Actualización de versiones de ofimática
# 172788503 Configuración de sistemas
# 172788504 Soporte a sistemas de ofimática
# 172788505 Soporte de periféricos
# 2013129324 Active Directory
# 2013129365 Citrix
# 2013129438 InfoVista
# 2013129669 Virtualbox
# 2013129673 VMware
# 172788303 Creación del modelo de datos
# 172788304 Data marts
# 172788305 Diseño de bases de datos
# 172788306 Administración de usuarios y accesos
# 172788307 Análisis de datos
# 172788308 Backup de bases de datos
# 172788309 Diagramas entidad-relación
# 172788310 Estándares de datos y API
# 172788311 Monitorización de bases de datos
# 172788312 Dimensionamiento de bases de datos
# 172788313 Rendimiento de bases de datos
# 172788314 Seguridad de datos
# 172788315 Migraciones de bases de datos
# 2013127126 Desarrollo de procesos de gestión de datos
# 2013127128 Estadística de bases de datos
# 2013127130 Indexación de datos para buscadores
# 2013127132 Protección de datos
# 2013129545 ORM (Object Relational Mapping)
# 172788035 Desarrollo cliente-servidor
# 172788097 Arquitectura de Software
# 172788098 Definición de metodología de desarrollo
# 172788099 Análisis funcional de aplicaciones
# 172788100 Especificación del diseño externo
# 172788101 Gestión de la Configuración
# 172788102 Definición de Requisitos
# 172788103 Revisión y depuración de código
# 172788104 Desarrollo de interfaces gráficas
# 172788105 Documentación Técnica
# 172788106 Documentación de hardware
# 172788107 Documentación de software
# 172788108 Especificación técnica
# 172788109 Integración de sistemas
# 2013127134 Arquitectura de la información
# 2013127136 Asesoría de estándares y herramientas
# 2013127138 Diseño de la usabilidad
# 2013127140 Metodologías de análisis
# 2013127142 Programación de aplicaciones web
# 2013127144 Programación estructurada
# 2013127146 Programación orientada a objetos
# 2013127148 Programación UML
# 2013129325 ActiveRecord
# 2013129333 Agile
# 2013129335 Ajax
# 2013129382 Despliegue de aplicaciones
# 2013129388 EAI Enterprise Application Integration
# 2013129391 EDA Event Driven Architecture
# 2013129406 eXtreme Programming
# 2013129418 Gestión de versiones
# 2013129500 MDA Model Driven Architecture
# 2013129536 OOA/OOD
# 2013129578 Requirement Management
# 2013129620 Scrum
# 2013129621 Security / Cryptography
# 2013129631 Sistemas distribuidos
# 2013129633 SOA Service Oriented Architecture
# 2013129659 UML
# 172788348 Apache HTTP Server
# 172788349 BEA Web Logic
# 172788350 Cold Fusion
# 172788351 IBM WebSphere
# 172788352 IIS (Internet Information Server)
# 172788353 Oracle Application Server
# 172788354 Sun Java Server
# 172788355 ATG Dynamo
# 172788356 BEA M3
# 172788357 BEA Tuxedo
# 172788358 Exchange
# 172788359 IBM MQ Series
# 172788360 Lotus cc:Mail
# 172788361 Lotus Notes
# 172788362 Lotus Notes-Domino
# 172788363 Microsoft Application Center Server
# 172788364 Microsoft BizTalk Server
# 172788365 Microsoft Commerce Server
# 172788366 Microsoft Content Management Server
# 172788368 Microsoft SharePoint Portal Server
# 172788369 MSMQ (Microsoft Message Queue)
# 172788370 Netscape Application Server
# 172788371 Netscape Enterprise Server
# 172788372 Oracle Internet Commerce Server
# 172788373 SMTP (Simple Mail Transfer Protocol)
# 172788374 Sybase Enterprise Application Server
# 172788375 TIBCO
# 2013129345 Apache Tomcat
# 2013129355 BEA Portal Server
# 2013129379 DB2 Connect
# 2013129387 Drupal
# 2013129397 EntireX
# 2013129430 IBM CICS
# 2013129432 IBM Lotus (Notes,  Domino)
# 2013129435 IMS DC
# 2013129462 JBoss
# 2013129471 Joomla
# 2013129490 Lotus Notes DB
# 2013129494 Magento
# 2013129495 Mambo
# 2013129509 Microsoft Exchange Server
# 2013129527 Novel Group Wise
# 2013129557 Postfix
# 2013129576 RedDot
# 2013129593 Samba
# 2013129637 SonicMQ
# 2013129657 TYPO3
# 2013129681 WebLogic Tuxedo Connector
# 172788563 Arquitectura de sistemas hardware
# 172788564 Desarrollo de circuitos integrados
# 172788565 Desarrollo de componentes de hardware
# 172788566 Desarrollo de sistemas embedded
# 172788567 Diseño de hadware analógico
# 172788568 Diseño de hardware digital
# 172788569 Diseño de circuitos integrados
# 172788570 Diseño de componentes de hardware
# 172788571 Diseño de hardware de lógica programable
# 172788572 Diseño de sistemas embedded
# 172788573 Compilación, enlace y construcción ROM
# 172788574 Programación de microcontroladores
# 172788575 Protocolos de comunicaciones
# 172788576 Prototipaje de hardware
# 172788577 Prueba de circuitos integrados
# 172788028 CRM (Customer Relationship Management)
# 172788029 Data Warehousing (OLAP)
# 172788038 EIS (Executive Information Systems)
# 172788039 GIS (Geographic Information Systems)
# 2013127150 Consultoría de Business Inteligence
# 2013127152 Data Mining
# 2013127154 DSS (Decision Support Systems)
# 2013127156 Estadística de bases de datos
# 2013127158 Instalación de plataformas BI
# 2013129374 Cognos
# 2013129402 Essbase
# 2013129566 QlikView
# 2013129598 SAP-BW Business Information Warehouse
# 2013129618 SAP-WM Warehouse management
# 172788110 Revisión de Código
# 172788111 Testing unitario de software
# 172788127 Diseño de test cases
# 172788128 Herramientas de test de software
# 172788129 Metodologías de test
# 172788130 Procedimientos de QA
# 172788131 Black Box Testing
# 172788132 Calidad del software
# 172788133 Estandares y Conceptos de QA
# 172788134 Planificación de test informáticos
# 172788136 Test de aceptación de software
# 172788137 Test de integración de software
# 172788138 Test de regresión de software
# 172788139 Test de sistemas
# 172788140 White Box Testing
# 2013129453 ISTQB Certified Tester
# 2013129483 JUnit
# 2013129622 Selenium
# 172788089 Definición de requerimientos de negocio
# 2013127160 Asesoría de aplicaciones sectoriales
# 2013127162 Asesoría de estándares informáticos
# 2013127164 Asesoría de plataformas de hardware
# 2013127166 Asesoría de telecomunicaciones
# 2013127168 Definición de requerimientos funcionales
# 172788030 ERP (Enterprise Resource Planning)
# 2013127170 Administración de plataformas ERP
# 2013127172 Consultoría pre-venta de soluciones ERP
# 2013127174 Desarrollo y parametrización ERP
# 2013127176 Implantación de plataformas ERP
# 2013127178 Planificación de proyectos ERP
# 2013127180 Reingeniería ERP de procesos
# 172788594 CMOS Integrated Circuit
# 172788595 Intel 80196
# 172788596 Intel 8051
# 172788597 M68000
# 172788598 BiCMOS
# 172788599 TI TMS320CxxDSP processor
# 172788600 TI TMS340xx processor
# 172788601 USB
# 172788114 Animación 3D multimedia
# 172788115 Diseño gráfico multimedia
# 172788116 Diseño gráfico web
# 172788117 Streaming de audio
# 172788118 Streaming de video
# 172788119 Definición de requerimientos multimedia
# 172788120 Plan de diseño visual
# 172788121 Plan de producción multimedia
# 172788122 Producción y edición multimedia
# 172788123 Prototipaje multimedia
# 172788124 Test de usabilidad
# 172788049 Reingeniería informática de procesos
# 2013127182 Compra de hardware
# 2013127184 Contratación de desarrollo de software
# 2013127186 Definición de RFP
# 2013127188 Despliegue de nuevas plataformas
# 2013127190 Dirección técnica de desarrollo
# 2013127192 Análisis de costes de telecomunicaciones
# 2013127194 Contratación de telecomunicaciones
# 2013127196 Coordinación de servicios de telefonía
# 2013127198 Gestión de proyectos de telecomunicación
# 2013127200 Presupuestos de telecomunicaciones
# 2013127202 Seguridad en telecomunicaciones
# 2013127204 Soporte a usuarios de telecomunicaciones
# 2013127206 Soporte a usuarios de telefonía
# 2013127208 Arquitectura de la información
# 2013127210 Diseño con Javascript
# 2013127212 Diseño de la usabilidad
# 2013127214 Diseño de plantillas de estilo
# 2013127216 Maquetación HTML
# 2013127218 Prototipaje y maquetación web
# 172788417 DHCP
# 172788418 DNS
# 172788419 IMAP
# 172788420 LDAP
# 172788421 SNMP
# 172788422 TCP/IP
# 172788423 Ethernet
# 172788424 FastEthernet
# 172788425 FDDI
# 172788426 HDLC (High-Level Data Link Control)
# 172788427 HTTP
# 172788428 IP (Internet Protocol)
# 172788429 LU6.2
# 172788430 NetBIOS
# 172788431 OSI
# 172788432 PPP
# 172788433 SNA (Systems Network Architecture)
# 172788434 SSH Secure Shell
# 172788435 Token Ring
# 172788436 X.25
# 172788437 X.400
# 172788438 X.500
# 2013129416 FTP
# 2013129644 SSL
# 172788580 Conversores A/D
# 172788581 Real Time Embedded System
# 172788582 Real Time Kernel/OS
# 172788583 Real Time Multi-Tasking System
# 172788584 SCADA
# 172788585 ArcView
# 172788586 Labview
# 172788587 RF Communication
# 172788588 ULSI
# 172788589 UNIX/Tornado Development
# 172788590 VLSI
# 172788591 ViewPrint
# 2013129425 Heroku
# 2013129575 Realtime Systems
# 2013129692 Windows Azure
# 172788604 RDSI
# 172788605 Voz sobre IP (VOIP)
# 172788606 WAP (Wireless Application Protocol)
# 172788607 i-mode
# 172788608 ATM (Asynchronous Transfer Mode)
# 172788609 DSL (and xDSL variations)
# 172788610 Fiber Optics
# 172788611 Fiber in the loop
# 172788612 Frame Relay
# 172788613 Lucent
# 172788614 NEC
# 172788615 PBX
# 172788616 SMS (Short Message Standard)
# 172788617 T1 / T3
# 172788618 Twisted Pair
# 172788619 WML
# 172788620 Wireless
# 2013129351 ASI Bus
# 2013129361 CAN Bus
# 2013129403 Ethernet Powerlink
# 2013129412 Flexray
# 2013129429 I2C Bus
# 2013129484 LIN Bus
# 2013129516 MOST Bus
# 2013129563 Profibus DP/PA
# 2013129634 SOAP
# 2013129684 WebServices
# 2013127220 Arquitectura de la información
# 2013127222 Categorización de contenidos
# 2013127224 Entrada y revisión de contenidos
# 2013127226 Estadística de bases de datos
# 2013127228 Indexación de datos para buscadores
# 2013127230 Posicionamiento en buscadores
# 2013129700 WordPress
# 172788078 Control de proyectos informáticos
# 172788079 Gestión de Cambios y Problemas
# 172788080 Gestión de Grandes Proyectos (12+ Meses)
# 172788081 Proyectos informáticos hasta 3 meses
# 172788082 Proyectos informáticos de más de 3 meses
# 172788083 Herramientas de gestión de proyectos
# 172788084 Liderazgo de Proyectos
# 172788085 Planificación de proyectos informáticos
# 172788086 Análisis de Viabilidad
# 172788087 Análisis financiero de proyectos
# 172788088 Análisis de Mercado
# 172788090 Gestión de recursos
# 172788091 Gestión de riesgos informáticos
# 172788092 Calidad de proyectos informáticos
# 172788093 Preparación de casos de negocio
# 172788094 Valoración de proyectos informáticos
# 2013129370 CMMI
# 2013129419 Gestión del cambio
# 2013129437 Incident Management
# 2013129455 ITIL
# 2013129553 PMI Project Management Institut
# 2013129554 PMP Project Managament Professional
# 2013129559 PPAP (Production Part Approval Process)
# 2013129560 Problem Management
# 2013129577 Release Management
# 2013129588 RUP Rational Unified Process
# 172788298 Gestión del acceso a Internet
# 172788299 Gestión del entorno Intranet
# 172788401 Administración de redes
# 172788402 Diseño y arquitectura de redes
# 172788403 Herramientas de gestión de redes
# 172788404 Dimensionamiento de redes
# 172788406 Ajuste de rendimiento de redes
# 172788407 Análisis de redes
# 172788408 Cableado de redes
# 172788410 Configuración de redes
# 172788411 Monitorización de redes
# 172788412 Procedimientos y estándares de redes
# 172788413 Protocolos de red
# 172788414 Servicios de acceso remoto
# 2013127232 Atención postventa informática
# 2013127234 Cuadros de mando y reports de servicio
# 2013127236 Definición de requerimientos funcionales
# 2013127238 Gestión de SLA informáticos
# 172788044 Image processing
# 2013127240 IBM content management
# 2013127242 Interwoven
# 2013127244 Kofax
# 2013127246 TIS
# 2013127248 Vignette
# 172788031 Gestión Documental
# 172788036 Document Imaging Systems
# 172788037 EDI (Electronic Data Interchange)
# 172788041 Gestión del conocimiento
# 172788518 Documentum
# 2013127250 Basware
# 2013127252 Captiva
# 2013127254 Docushare
# 2013127256 Filenet
# 2013127258 Hummingbird
# 172788042 Groupware
# 172788050 Workflow Automation
# 2013127260 BPM (Business Process Management)
# 2013127262 BSCW
# 2013127264 Consultoría de Lotus Notes
# 2013127266 Groove
# 2013129330 Adonis
# 2013129350 ARIS
# 2013129561 Process4Biz
# 2013129565 Promet@work
# 2013129624 Semtalk
# 172788143 Delphi
# 172788144 IBM VisualAge Java
# 172788145 Jbuilder
# 172788146 Oracle Developer/2000
# 172788147 Visual Basic (VB)
# 172788148 Visual C#
# 172788149 Visual C++ (Microsoft)
# 172788150 ABC Flowcharter
# 172788151 Astra Quick Test
# 172788152 Borland C++
# 172788153 Broadvision
# 172788154 C#
# 172788155 CA-Clipper
# 172788156 CA-Ideal
# 172788157 CVS
# 172788158 ClearCase (Rational)
# 172788159 EasyTrieve
# 172788160 Expersoft CORBAplus
# 172788161 Foundation (Andersen)
# 172788162 Gupta SQL Windows
# 172788163 IBM VisualAge Smalltalk
# 172788164 Informix 4GL/SQL
# 172788165 InstallShield
# 172788166 Lint
# 172788167 ObjectVision
# 172788168 ObjectView
# 172788169 Oracle CASE
# 172788170 Oracle Forms
# 172788171 Oracle J Developer
# 172788173 Oracle ReportWriter
# 172788174 Oracle SQL*Forms
# 172788175 PVCS
# 172788176 Perforce
# 172788177 PowerBuilder
# 172788178 Purify (Rational)
# 172788179 Quantify (Rational)
# 172788180 Rational Apex
# 172788182 Rational Rose
# 172788183 RoboHELP
# 172788184 Rumba
# 172788185 Sun Java Studio / Workshop
# 172788186 Sun Visual Workshop C++
# 172788187 Sybase PowerJ
# 172788188 Symantec Visual Café
# 172788189 Systems Architect
# 172788190 TeamTest (Rational)
# 172788191 Visual C++ (IBM)
# 172788192 Visual FoxPro
# 172788193 Visual InterDev
# 172788194 Visual J#
# 172788195 Visual J++
# 172788196 Visual Objects
# 172788197 Visual SourceSafe
# 172788198 VisualAge Generator
# 172788199 VisualTest (Rational)
# 172788239 Blue Martini
# 172788241 IBM Net.Commerce
# 172788242 NetObjects Fusion
# 172788243 Ariba e-Commerce Solution
# 172788244 HomeSite
# 172788245 Hot Metal Pro
# 172788246 Information Builders WebFocus
# 172788247 Versata
# 2013129327 Adobe Air
# 2013129336 Allfusion:Gen
# 2013129338 Apache Ant
# 2013129342 Apache Maven
# 2013129371 Cocoa
# 2013129375 COOL:Gen
# 2013129376 cURL
# 2013129389 Eclipse
# 2013129390 Eclipse RCP
# 2013129393 Emacs
# 2013129417 GCC
# 2013129420 Git
# 2013129421 Github
# 2013129439 IntelliJ IDEA
# 2013129465 JDeveloper
# 2013129473 JProbe
# 2013129474 JProfiler
# 2013129503 Mercurial
# 2013129504 Mercury LoadRunner
# 2013129505 Mercury WinRunner
# 2013129515 Mono
# 2013129519 MSBuild
# 2013129524 NetBeans
# 2013129570 Rational ClearQuest
# 2013129571 Rational Funtional Tester
# 2013129572 Rational Robot
# 2013129573 Rational Software Architect
# 2013129574 Rational Software Modeler
# 2013129647 SubVersion
# 2013129649 SVN
# 2013129668 Vim
# 2013129672 Visual Studio
# 2013129704 Xcode
# 2013129706 XNA
# 172788240 FrontPage
# 172788283 3D Studio
# 172788284 Adobe Photoshop
# 172788285 Macromedia Director / Shockwave
# 172788286 Macromedia Dreamweaver/Fireworks
# 172788287 Apple Quick Time
# 172788288 CorelDraw
# 172788289 Macromedia Authorware
# 172788290 Freehand
# 172788291 Paint Shop Pro
# 172788292 QuarkXPress
# 172788513 Adobe PageMaker
# 2013127268 Flash
# 2013127270 Quark Express
# 2013129309 Indesign
# 2013129310 Adobe Illustrator
# 2013129322 3D Studio Max
# 2013129329 Adobe InDesign
# 2013129499 Maya
# 2013129654 TeX/LaTeX
# 172788508 Goldmine
# 172788509 Map Objects
# 172788510 Microstrategy DSS
# 172788528 Oracle Financials
# 172788529 Oracle Manufacturing
# 172788530 PeopleSoft Distribution
# 172788531 PeopleSoft Human Resources
# 172788532 SAP R/3 Financials
# 172788533 SAP R/3 Human Resources
# 172788534 SAP R/3 Sales and Distribution
# 172788535 Siebel
# 172788536 Vantive
# 172788537 BAAN IV
# 172788538 Clarify
# 172788539 Computer Associates Enterprise Apps
# 172788540 Great Plains
# 172788541 JD Edwards
# 172788542 Oracle 11.x Applications
# 172788543 Oracle Customer Relationship Management
# 172788544 Oracle Distribution
# 172788545 Oracle Human Resources
# 172788546 Oracle Projects
# 172788547 Oracle Supply Chain
# 172788548 PeopleSoft Financials
# 172788549 PeopleSoft Manufacturing
# 172788550 PeopleSoft Materials Management
# 172788551 PeopleSoft Supply Chain
# 172788552 Peregrine
# 172788553 Remedy
# 172788554 SAP R/3 General
# 172788555 SAP R/3 Manufacturing
# 172788556 SAP R/3 Materials Management
# 172788557 SAP/R2
# 172788558 SAS EIS Software
# 172788559 Trilogy
# 2013127272 DSS Agent
# 2013129431 IBM ERP
# 2013129506 Microsoft Dynamics AX (Axapta)
# 2013129507 Microsoft Dynamics CRM
# 2013129508 Microsoft Dynamics NAV (Navision)
# 2013129521 MySAP ERP
# 2013129544 Oracle E-Business Suite
# 2013129549 PeopleSoft
# 2013129591 Sage Software
# 2013129592 SalesForce CRM
# 2013129595 SAP CRM
# 2013129597 SAP R3
# 2013129599 SAP-CFM Corporate Finance Management
# 2013129600 SAP-CO Controlling
# 2013129601 SAP-CS Customer Service
# 2013129602 SAP-EC Enterprise Controlling
# 2013129603 SAP-FI Finance
# 2013129604 SAP-HR Human Resources
# 2013129605 SAP-LE Logistics Execution
# 2013129606 SAP-LO Logistics General
# 2013129607 SAP-MM Material Management
# 2013129608 SAP-PA Personnel Administration
# 2013129609 SAP-PLM Product Lifecycle Management
# 2013129610 SAP-PM Plant Maintenance
# 2013129611 SAP-PP Product Planning
# 2013129612 SAP-PS Project System
# 2013129613 SAP-QM Quality Management
# 2013129614 SAP-SCM Supply Chain Management
# 2013129615 SAP-SD Sale & Distribution
# 2013129616 SAP-SEM Strategic Enterprise Management
# 2013129617 SAP-SRM Supplier Relationship Management
# 2013129628 Siebel CRM Systems
# 2013129642 SSA ERP (Baan)
# 172788032 Informática en e-commerce
# 172788033 Automatización de la fuerza de ventas
# 172788040 Informática en gestión de stocks
# 172788043 HRIS (Human Resource Info Systems)
# 172788045 Inteligencia artificial y sistemas expertos
# 172788046 Investigación y Desarrollo & Development
# 172788047 Multimedia
# 172788048 OLTP (Online Transaction Processing)
# 172788053 Informática aplicada a sector automoción
# 172788054 Informática en ventas
# 172788055 Informática en sector distribución
# 172788057 Informática en sector financiero
# 172788058 Informática en sector seguros
# 172788059 Informática en sector informático
# 172788060 Informática en sector telecomunicaciones
# 172788061 Informática en sector construcción
# 172788063 Informática en sector ocio
# 172788064 Informática en industria
# 172788065 Informática en administración pública
# 172788067 Informática en marketing
# 172788068 Informática en sector sanitario
# 172788069 Informática en sector editorial
# 172788070 Informática en sector energético
# 172788071 Informática en sector farmacéutico
# 172788072 Informática en sector legal
# 172788073 Informática en sector transportes
# 172788074 Informática en defensa militar
# 172788075 Informática en sector utilities
# 2013127274 CAD
# 2013127276 CAE
# 2013127278 CAM
# 2013129314 Informatica en consumo
# 2013129316 Informatica en educacion y formacion
# 2013127280 Arquitectura de telecomunicaciones
# 2013127282 Coordinación de instalación de redes
# 2013127284 Gestión de proyectos de telecomunicación
# 2013127286 Ingeniería de cable y fibra óptica
# 172789052 Cableado telefónico y de TV
# 2013127288 Configuración de conectividad
# 2013127290 Instalación de redes de voz
# 2013127292 Instalación de redes locales
# 2013127294 Instalación de servidores de red
# 2013127296 Recepción y difusión de radio y TV
# 2013127298 Redes inalámbricas
# 172788202 C++
# 172788203 HTML
# 172788204 Java
# 172788205 JavaScript
# 172788206 PHP
# 172788207 SQL
# 172788208 ABAP/4
# 172788209 Actionscript (Flash)
# 172788210 Awk
# 172788211 Basic
# 172788212 C Language
# 172788213 CFML
# 172788214 CICS
# 172788215 COBOL
# 172788216 CSS (Cascading Style Sheets)
# 172788217 DHTML
# 172788218 Ensamblador
# 172788219 JCL
# 172788220 LISP
# 172788221 MICROFOCUS Cobol
# 172788222 NATURAL / NATURAL II
# 172788223 Oracle SQL*Plus
# 172788224 Pascal
# 172788225 Perl
# 172788226 PL/1
# 172788227 PL/SQL
# 172788228 Python
# 172788229 Swing
# 172788230 UNIX Shell Scripting
# 172788231 VB Script
# 172788232 VBA (Microsoft Access / Office)
# 172788233 XML
# 172788234 XSL
# 2013129321 .NET
# 2013129326 Ada
# 2013129328 Adobe Flex
# 2013129366 CL/400
# 2013129367 Clarion
# 2013129368 Clipper
# 2013129369 Clojure
# 2013129380 dBase
# 2013129392 Eiffel
# 2013129394 Embedded C++
# 2013129395 Embedded Java
# 2013129399 Erlang
# 2013129401 ESQL
# 2013129407 F#
# 2013129413 Focus
# 2013129414 Forth
# 2013129415 Fortran
# 2013129423 Groovy
# 2013129424 Haskell
# 2013129428 HTML5
# 2013129460 Java2E
# 2013129485 Lingo
# 2013129486 LINQ
# 2013129489 Logo
# 2013129491 Lotus Notes Script
# 2013129496 Maple
# 2013129497 Matlab
# 2013129511 ML
# 2013129513 Modula
# 2013129522 Natural
# 2013129532 Object Pascal
# 2013129533 Objective Caml
# 2013129534 Objective-C
# 2013129551 PL1
# 2013129558 PostScript
# 2013129564 Prolog
# 2013129569 R
# 2013129580 REXX
# 2013129584 RPG
# 2013129585 Ruby
# 2013129586 Ruby On Rails
# 2013129619 SCALA
# 2013129629 Silverlight
# 2013129632 Smalltalk
# 2013129638 SPARQL
# 2013129639 Spring
# 2013129645 Step 7
# 2013129656 Transact-SQL
# 2013129662 Unix
# 2013129665 VBA
# 2013129666 VBScript
# 2013129667 VHDL
# 2013129670 Visual Basic
# 2013129671 Visual C++
# 2013129678 WebDNA
# 2013129683 WebQL
# 2013129697 Windows Power Shell
# 2013129699 WinForms
# 2013129701 WPF (Windows Presentation Fundation)
# 2013129702 XAML (eXtensible Application Markup Language)
# 2013129705 XHTML
# 2013129707 Xpath
# 2013129708 XSLT
# 172788250 ASP (Active Server Pages)
# 172788251 COM+
# 172788252 CORBA
# 172788253 DCOM (Microsoft)
# 172788254 EJB (Enterprise Java Beans)
# 172788255 J2EE
# 172788256 JDBC
# 172788257 ODBC
# 172788258 UML (Unified Modeling Language)
# 172788259 Active X
# 172788260 ADO (ActiveX Data Objects)
# 172788261 ASP.NET (ASP+)
# 172788262 COM (Microsoft)
# 172788263 DOM (Document Object Model)
# 172788264 Java Native Interface (JNI)
# 172788265 Java RMI (Remote Method Invocation)
# 172788266 JavaBeans
# 172788267 JFC (Java Foundation Classes)
# 172788268 Jini
# 172788269 JSP (Java Server Page)
# 172788270 MAPI (Messaging API)
# 172788271 MFC
# 172788272 Microsoft .NET Framework
# 172788273 Oracle Call Interface (OCI)
# 172788274 ORB
# 172788275 Rapid Application Development (RAD)
# 172788276 Servlet
# 172788277 SOAP (Simple Object Access Protocol)
# 172788278 TAPI (Telephony API)
# 172788279 Unified Process
# 172788280 VB.NET
# 2013129332 ADT (Android Development Tools)
# 2013129339 Apache Axis
# 2013129340 Apache FOP
# 2013129341 Apache Jmeter
# 2013129343 Apache Solr
# 2013129344 Apache Tapestry
# 2013129346 Apache Velocity
# 2013129347 Appcelerator
# 2013129353 Backbone.js
# 2013129360 CakePHP
# 2013129372 Cocoa Touch
# 2013129373 CodeIgniter
# 2013129383 Django
# 2013129385 Doctrine
# 2013129386 Dojo
# 2013129405 ExtJs
# 2013129422 Grails
# 2013129426 Hibernate
# 2013129454 iText
# 2013129456 JAAS
# 2013129457 Jasper Report
# 2013129458 Java ME
# 2013129459 Java Web Start
# 2013129461 JavaMail
# 2013129464 JDBC
# 2013129466 JDO
# 2013129467 JMS
# 2013129468 JMX
# 2013129469 JNDI
# 2013129470 JNI
# 2013129472 JPA (Java Persistence API)
# 2013129475 jQuery
# 2013129476 jQuery Grid
# 2013129477 jQuery Mobile
# 2013129478 JSF
# 2013129479 JSF (JavaServer Faces)
# 2013129480 JSON
# 2013129481 JSP
# 2013129482 JSTL
# 2013129488 Log4J
# 2013129492 Lucene
# 2013129512 mod_rewrite
# 2013129517 MoSync
# 2013129525 node.js
# 2013129529 NSString
# 2013129530 NumPy
# 2013129531 Oauth
# 2013129538 OpenCV (Open source Computer Vision)
# 2013129539 OpenGL
# 2013129541 OptimizeIT
# 2013129550 PhoneGap
# 2013129556 Portlets
# 2013129567 Qt
# 2013129579 REST
# 2013129581 RhoMobile
# 2013129583 RMI
# 2013129587 RubyGems
# 2013129596 SAP NetWeaver
# 2013129626 Servlets
# 2013129640 spring-mvc
# 2013129643 SSIS (SQL Server Integration Services)
# 2013129646 Struts
# 2013129651 Symfony
# 2013129661 Unity
# 2013129679 WebForms
# 2013129680 WebKit
# 2013129685 WebView
# 2013129686 WebWork
# 2013129687 Whoop
# 2013129688 WidgetPad
# 172788367 Microsoft Outlook
# 172788514 Microsoft Excel
# 172788515 Microsoft Word
# 172788516 Corel Word Perfect
# 172788519 Lotus 123
# 172788520 Microsoft Internet Explorer
# 172788521 Microsoft Office
# 172788522 Microsoft PowerPoint
# 172788523 Microsoft Project
# 172788525 Netscape Communicator / Navigator
# 172788924 Procesadores de texto
# 172788925 Hojas de cálculo
# 172788926 Presentaciones gráficas
# 172788927 Uso de bases de datos
# 172788929 Correo electrónico
# 172788930 Uso de Windows
# 172788931 Uso de Mac OS
# 2013127300 Mozilla Firefox
# 2013127302 Navegador Opera
# 2013129410 Firefox
# 2013129590 Safari
# 172788517 Doc-To-Help
# 172788524 Microsoft Visio
# 2013127304 AutoCad
# 2013127306 Contaplus
# 2013127308 Facturaplus
# 2013127310 Software Presto
# 2013127312 SPSS
# 2013129349 ArchiCAD
# 2013129352 AutoDesk
# 2013129359 CADdy
# 2013129362 CATIA CADAM
# 2013129441 Intergraph
# 2013129442 Inventor
# 2013129501 Mechanical Desktop
# 2013129510 Microstation
# 2013129526 Nominaplus
# 2013129548 PDMS
# 2013129562 ProE
# 2013129589 Ruplan
# 2013129635 SolidEdge
# 2013129636 SolidWorks
# 2013129660 Unigraphics NX
# 2013129689 Wildfire
# 172788481 AS/400
# 172788482 HP9000
# 172788483 IBM Mainframe
# 172788484 IBM RS/6000
# 172788485 Intel based PCs
# 172788486 Sun
# 172788487 Bull
# 172788488 DEC VAX
# 172788489 HP3000
# 172788490 IBM 9000
# 172788491 IBM S390
# 172788492 IBM System 38 / 36
# 172788493 Macintosh
# 172788494 PLC (Programmable Logic Controller)
# 172788495 Unysis
# 2013129444 iPad
# 2013129445 iPhone
# 2013129582 RIM
# 172788380 Encriptado y seguridad web
# 172788383 Gestión de riesgos de seguridad
# 172788386 Instalación de firewall
# 172788389 PKI (public key infrastructure)
# 172788391 Política de seguridad informática
# 172788392 Protocolos de comunicación mainframe
# 172788405 Seguridad
# 172788409 Configuración de firewall
# 2013127314 Administración de seguridad de redes
# 2013127316 Auditoría de seguridad informática
# 2013127318 Plan de contingencias informáticas
# 2013127320 Protección de datos
# 2013127322 Seguridad en telecomunicaciones
# 172788462 Linux
# 172788463 Unix
# 172788464 Windows 2000 Professional
# 172788465 Windows 2000 Server
# 172788466 IBM OS / 400
# 172788467 Mvs
# 172788469 OS/2 Warp
# 172788470 OS/390
# 172788471 TSO
# 172788472 Unix (AIX)
# 172788473 Unix (HP-UX)
# 172788474 Unix (Sun Solaris)
# 172788475 VMS
# 172788476 Windows 98
# 172788477 Windows NT 4
# 172788478 Windows XP
# 2013127324 Mac OS
# 2013129334 AIX
# 2013129337 Android
# 2013129348 Apple IOS
# 2013129354 Bada
# 2013129356 Blackberry OS
# 2013129357 BS2000
# 2013129363 CentOS
# 2013129396 Embedded Linux
# 2013129427 HP-UX
# 2013129443 iOS
# 2013129446 IRIX
# 2013129487 Linux Ubuntu
# 2013129493 Maemo
# 2013129502 MeeGo
# 2013129518 MS Windows Server 2000/2003
# 2013129520 MVS/OS-390
# 2013129528 Novell
# 2013129537 OpenBSD
# 2013129546 OS/400
# 2013129630 Sinix
# 2013129648 Sun OS / Solaris
# 2013129650 Symbian
# 2013129652 Tandem
# 2013129655 TOS
# 2013129658 uClinux (microClinux)
# 2013129663 Unix General
# 2013129664 Unix SCO
# 2013129676 VxWorks
# 2013129682 WebOS
# 2013129690 Windows
# 2013129691 Windows 95/98/Me
# 2013129693 Windows CE
# 2013129694 Windows Mobile
# 2013129695 Windows NT
# 2013129696 Windows Phone
# 2013129698 Windows XP/2000/Vista
# 2013129709 z/OS
# 2013127326 Atención telefónica de usuarios
# 2013127328 Coordinación de equipos en helpdesk
# 2013127330 Definición de SLA
# 2013127332 Herramientas de ticketing
# 2013127334 Monitorización de infraestructuras
# 111111111 PostgreSQL
# 172788318 Access
# 172788319 Crystal Reports
# 172788320 DB2 (Including Universal Database)
# 172788321 Informix
# 172788322 Oracle 8/8i
# 172788323 Oracle 9.x
# 172788324 Oracle Designer/2000
# 172788325 Oracle Express
# 172788326 SQL Server
# 172788327 ADABAS
# 172788328 BusinessObjects
# 172788329 COGNOS Impromptu
# 172788330 COGNOS PowerPlay
# 172788331 Discoverer 2000/3000
# 172788332 FoxPro
# 172788333 Gupta SQL
# 172788334 IBM Intelligent Miner
# 172788335 IBM Visual Warehouse
# 172788336 Informix 9.x / Illustra Universal Server
# 172788337 Informix Datablades
# 172788338 Informix Metacube
# 172788339 Informix XPS
# 172788340 INGRES
# 172788341 MySQL
# 172788342 Oracle 7 or earlier
# 172788343 PROGRESS
# 172788344 Sybase
# 172788345 Sybase PowerDesigner
# 2013129323 4th Dimension
# 2013129358 Btrieve
# 2013129364 Centura
# 2013129377 Data Modeling
# 2013129378 DB/400
# 2013129381 Derby
# 2013129384 DL/I
# 2013129398 ER Model
# 2013129400 ERwin
# 2013129404 ETL Extract/Transform/Load
# 2013129408 FileMaker Pro
# 2013129409 Firebird
# 2013129434 IDMS
# 2013129436 IMS/DB
# 2013129440 Interbase
# 2013129447 ISAM
# 2013129463 JDataStore
# 2013129498 MaxDB (SAP DB)
# 2013129514 MongoDB
# 2013129523 neo4j
# 2013129540 OpenOffice.org Base
# 2013129542 Oracle 10.x
# 2013129543 Oracle 11.x
# 2013129547 Parodox
# 2013129555 POET
# 2013129568 Quest TOAD
# 2013129627 SESAM
# 2013129641 SQLite
# 2013129653 Teradata
# 2013129675 VSAM
# 2013129703 xBase / dBase
# 172788441 Cisco Routers
# 172788442 HP OpenView
# 172788443 IBM Lan Server
# 172788444 Netview 6000
# 172788445 3Com
# 172788446 ArcServe
# 172788447 Cisco IOS
# 172788448 Hubs/Routers
# 172788449 LAN Manager
# 172788450 Laplink
# 172788451 Microsoft Active Directory
# 172788452 Microsoft Host Integration Server
# 172788453 MS Internet security & acceleration server
# 172788454 Microsoft Mobile Information Server
# 172788455 Netscape Directory Server
# 172788456 NFS (Network File System)
# 172788457 SAN (Storage File System)
# 172788458 VTAM
# 172788459 WAN (Wide Area Network)
# 2013129411 Firewall
# 2013129433 IBM SNA
# 2013129594 SAN System Area Network
# 2013129674 VPN
# 2013129677 WAN/LAN
# 2013127336 Venta de aplicaciones de gestión
# 2013127338 Venta de aplicaciones servidor y BBDD
# 2013127340 Venta de business inteligence
# 2013127342 Venta de desarrollo host
# 2013127344 Venta de desarrollo multimedia
# 2013127346 Venta de desarrollo web
# 2013127348 Venta de entornos ERP
# 2013127350 Venta de entornos mainframe
# 2013127352 Venta de gestión documental
# 2013127354 Venta de impresión digital
# 2013127356 Venta de microinformática
# 2013127358 Venta de servicios de helpdesk
# 2013127360 Venta de servicios de mantenimiento
# 2013127362 Venta de servidores de red
# 2013127364 Venta de telecomunicaciones
# 2013127366 Venta de telefonía y conectividad
# 2013127368 Venta y outsourcing de servicios

# %%
def skills_to_applicant(skills, M, v):
    applicant = []
    print("Applicant skills: ")
    for i in v:
        if int(i) in skills: applicant.append(1)
        else: applicant.append(0)
    return applicant

M, sc_matrix, v = retrieve_data()
len(skills_to_applicant([172788310, 2013129692, 172788091], M, v)) == len(v)
# Out:
# Applicant skills:
# True

# %%
def skillid_to_name(skillids, skills):
    tmp = []
    for i in skillids:
        if str(i) in skills:
            print(skills[str(i)])
            #tmp.append(skills[str(i)])

# %%
def exec():
    M, sc_matrix, v = retrieve_data()
    n = len(v)
    # print(M) # works
    # print(sc_matrix) #works

    # generate an applicant profile
    #K = 1
    #for i in range(n):
    #    if K > 0:
    #        applicant.append(1)
    #    else:
    #        applicant.append(0)
    #    K *= -1
    # now we should have a real applicant
    
    skills = [2013129692, 2013129700, 2013127224]
    applicant = skills_to_applicant(skills, M, v)
    skillid_to_name(skills, v)
    print("\nRecomendations:")
    # 172788310, 
    Q = pq(build_first(sc_matrix, applicant, k), k)
    search_engine(Q, sc_matrix, applicant)
    v = Q.queue_to_list()
    rc_sc_id = {}
    for i in range(len(v)):
        rc_sc_id[M[str(v[i][-2])]] = 0
    return list(rc_sc_id)[:k]


print(exec())
# elements in the queue will be [v,'id', d(v,u)**2] where u is the application.
# the application has format [u,w,0] where w is the vector containing applicable information.
# compare with d(u,v)**2
# Out:
# Applicant skills:
# Windows Azure
# WordPress
# Entrada y revisión de contenidos
#
# Recomendations:
# ['Desarrollo multimedia', 'Consultoría de sistemas', 'Consultoría y desarrollo ERP', 'Desarrollo de firmware', 'Dirección técnica de sistemas de información', 'Dirección y gestión de telecomunicaciones', 'Diseño web', 'Estándares y tecnologías de hardware', 'Estándares y tecnologías de telecomunicación', 'Gestión de contenidos']
